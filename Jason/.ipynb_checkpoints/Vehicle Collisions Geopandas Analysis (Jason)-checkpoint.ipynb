# %%
#data handling/modeling
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
import scipy.stats as stats

# visualization
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# %%
data = pd.read_csv(r"C:\Users\Jason Liu\Desktop\InsightTeam2020\Motor_Vehicle_Collisions_-_Crashes.csv")
print(data.dtypes)
print(data.shape)
# Out:
# CRASH DATE                        object
# CRASH TIME                        object
# BOROUGH                           object
# ZIP CODE                         float64
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCATION                          object
# ON STREET NAME                    object
# CROSS STREET NAME                 object
# OFF STREET NAME                   object
# NUMBER OF PERSONS INJURED        float64
# NUMBER OF PERSONS KILLED         float64
# NUMBER OF PEDESTRIANS INJURED      int64
# NUMBER OF PEDESTRIANS KILLED       int64
# NUMBER OF CYCLIST INJURED          int64
# NUMBER OF CYCLIST KILLED           int64
# NUMBER OF MOTORIST INJURED         int64
# NUMBER OF MOTORIST KILLED          int64
# CONTRIBUTING FACTOR VEHICLE 1     object
# CONTRIBUTING FACTOR VEHICLE 2     object
# CONTRIBUTING FACTOR VEHICLE 3     object
# CONTRIBUTING FACTOR VEHICLE 4     object
# CONTRIBUTING FACTOR VEHICLE 5     object
# COLLISION_ID                       int64
# VEHICLE TYPE CODE 1               object
# VEHICLE TYPE CODE 2               object
# VEHICLE TYPE CODE 3               object
# VEHICLE TYPE CODE 4               object
# VEHICLE TYPE CODE 5               object
# NUMTIME                          float64
# dtype: object
# (1048575, 30)

# %%
data.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE LOCATION  \
# 0  11/26/2015      11:55       NaN       NaN       NaN        NaN      NaN
# 1    4/4/2020      21:07       NaN       NaN       NaN        NaN      NaN
# 2    4/3/2020      23:05       NaN       NaN       NaN        NaN      NaN
# 3    5/3/2016       7:47  BROOKLYN   11221.0       NaN        NaN      NaN
# 4    4/1/2020       7:56       NaN       NaN       NaN        NaN      NaN
#
#                      ON STREET NAME CROSS STREET NAME OFF STREET NAME  ...  \
# 0                               NaN               NaN             NaN  ...
# 1  BELT PARKWAY RAMP                              NaN             NaN  ...
# 2  VANWYCK EXPRESSWAY                  LIBERTY AVENUE             NaN  ...
# 3  DE KALB AVENUE                        LEWIS AVENUE             NaN  ...
# 4  WILLIAMSBURG BRIDGE INNER ROADWA               NaN             NaN  ...
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  VEHICLE TYPE CODE 1  \
# 0                            NaN       3342409    PASSENGER VEHICLE
# 1                            NaN       4307578                Sedan
# 2                            NaN       4307510                Sedan
# 3                            NaN       3435102    PASSENGER VEHICLE
# 4                            NaN       4305034                Sedan
#
#    VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  VEHICLE TYPE CODE 4  \
# 0                  VAN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2        Pick-up Truck                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  NaN                  NaN                  NaN
#
#   VEHICLE TYPE CODE 5 NUMTIME
# 0                 NaN   11.92
# 1                 NaN   21.12
# 2                 NaN   23.08
# 3                 NaN    7.78
# 4                 NaN    7.93
#
# [5 rows x 30 columns]

# %%
#data=data[['LATITUDE','LONGITUDE','ON STREET NAME','CONTRIBUTING FACTOR VEHICLE 1','CONTRIBUTING FACTOR VEHICLE 2']]
print(data['LATITUDE'].isna().sum())
print(data['LONGITUDE'].isna().sum())
print((data['LATITUDE']==0).sum())
print((data['LONGITUDE']==0).sum())
# Out:
# 103076
# 103076
# 1168
# 1168

# %%
import geopy
import geocoder
import geopandas as gpd
from geopandas.tools import geocode
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="user")
location = geolocator.geocode("Flatbush Avenue NYC")
print(location.address)
print(location.latitude,location.longitude)
# Out:
# Flatbush Avenue, Gerritsen, Brooklyn, Kings County, New York, 11234, United States of America
# 40.5983056 -73.9098775

# %%
data['ON STREET NAME'] = data['ON STREET NAME']+' NYC'
data.head(10)
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0  11/26/2015      11:55       NaN       NaN        NaN        NaN
# 1    4/4/2020      21:07       NaN       NaN        NaN        NaN
# 2    4/3/2020      23:05       NaN       NaN        NaN        NaN
# 3    5/3/2016       7:47  BROOKLYN   11221.0        NaN        NaN
# 4    4/1/2020       7:56       NaN       NaN        NaN        NaN
# 5   3/29/2020       7:16       NaN       NaN        NaN        NaN
# 6   3/28/2020      20:40       NaN       NaN        NaN        NaN
# 7   3/28/2020       9:40    QUEENS   11420.0  40.678295 -73.808075
# 8   3/27/2020       6:48       NaN       NaN        NaN        NaN
# 9   4/15/2016      17:00       NaN       NaN        NaN        NaN
#
#                        LOCATION                        ON STREET NAME  \
# 0                           NaN                                   NaN
# 1                           NaN  BELT PARKWAY RAMP                NYC
# 2                           NaN  VANWYCK EXPRESSWAY               NYC
# 3                           NaN  DE KALB AVENUE                   NYC
# 4                           NaN  WILLIAMSBURG BRIDGE INNER ROADWA NYC
# 5                           NaN  BELT PARKWAY RAMP                NYC
# 6                           NaN  CONNER STREET                    NYC
# 7  POINT (-73.808075 40.678295)  132 STREET                       NYC
# 8                           NaN  ROCKAWAY BOULEVARD               NYC
# 9                           NaN  RFK BRIDGE BRONX TOLL PLZ, R/W 2 NYC
#
#       CROSS STREET NAME OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                   NaN             NaN  ...                            NaN
# 1                   NaN             NaN  ...                            NaN
# 2        LIBERTY AVENUE             NaN  ...                            NaN
# 3          LEWIS AVENUE             NaN  ...                            NaN
# 4                   NaN             NaN  ...                            NaN
# 5                   NaN             NaN  ...                            NaN
# 6      TILLOTSON AVENUE             NaN  ...                            NaN
# 7            116 AVENUE             NaN  ...                            NaN
# 8  BROOKVILLE BOULEVARD             NaN  ...                            NaN
# 9                   NaN             NaN  ...                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN                            NaN       3342409
# 1                            NaN                            NaN       4307578
# 2                            NaN                            NaN       4307510
# 3                            NaN                            NaN       3435102
# 4                            NaN                            NaN       4305034
# 5                            NaN                            NaN       4307777
# 6                            NaN                            NaN       4304536
# 7                            NaN                            NaN       4304582
# 8                            NaN                            NaN       4304114
# 9                            NaN                            NaN       3409945
#
#    VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  \
# 0    PASSENGER VEHICLE                  VAN                  NaN
# 1                Sedan                  NaN                  NaN
# 2                Sedan        Pick-up Truck                  NaN
# 3    PASSENGER VEHICLE                  NaN                  NaN
# 4                Sedan                  NaN                  NaN
# 5            Box Truck            Box Truck                  NaN
# 6                Sedan                  NaN                  NaN
# 7                Sedan                  NaN                  NaN
# 8                Sedan                Sedan                  NaN
# 9    PASSENGER VEHICLE    PASSENGER VEHICLE                  NaN
#
#    VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5 NUMTIME
# 0                  NaN                 NaN   11.92
# 1                  NaN                 NaN   21.12
# 2                  NaN                 NaN   23.08
# 3                  NaN                 NaN    7.78
# 4                  NaN                 NaN    7.93
# 5                  NaN                 NaN    7.27
# 6                  NaN                 NaN   20.67
# 7                  NaN                 NaN    9.67
# 8                  NaN                 NaN    6.80
# 9                  NaN                 NaN   17.00
#
# [10 rows x 30 columns]

# %%
#created a concatenated list of all 
data = data[['BOROUGH','LONGITUDE','LATITUDE','ON STREET NAME']]
zero_data = data[data['LONGITUDE'].eq(0)]
empty_data = data.loc[data[['LONGITUDE','LATITUDE']].isna().any(axis=1)]
null_data = pd.concat([empty_data,zero_data])
null_data = null_data[null_data['ON STREET NAME'].notna()]
null_data.head(20)
null_data.to_csv(r"C:\Users\Jason Liu\Desktop\InsightTeam2020\addresses.csv", index = False, header = True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-10-ccba11802f87> in <module>
#       6 null_data = null_data[null_data['ON STREET NAME'].notna()]
#       7 null_data.head(20)
# ----> 8 null_data.to_csv(r"C:\Users\Jason Liu\Desktop\InsightTeam2020\addresses.csv", index = False, header = True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\Jason Liu\\Desktop\\InsightTeam2020\\addresses.csv'

# %%
from geopy.exc import GeocoderTimedOut

def geocodelong(address):
    geolocator = Nominatim(user_agent="user")
    location = geolocator.geocode(address)
    try:
        return location.longitude
    except GeocoderTimedOut:
        return do_geocode(address)
    except AttributeError:
        return 0

def geocodelat(address):
    geolocator = Nominatim(user_agent="user")
    location = geolocator.geocode(address)
    try:
        return location.latitude
    except GeocoderTimedOut:
        return do_geocode(address)
    except AttributeError:
        return 0
        
def getlong(address):
    geolocator = Nominatim(user_agent="user")
    location = geolocator.geocode(address)
    try:
        return location.longitude
    except AttributeError:
        return 0
def getlat(address):
    geolocator = Nominatim(user_agent="user")
    location = geolocator.geocode(address)
    try:
        return location.latitude
    except AttributeError:
        return 0
def getaddress(address):
    geolocator = Nominatim(user_agent="user")
    location = geolocator.geocode(address)
    try:
        return location.address
    except AttributeError:
        return 0
geocodelong('91 AVENUE NYC')

# %%
#getlong(null_data['ON STREET NAME'].iloc[9]) 
#-73.724982
#null_data['N_LONG'] = getlong(null_data['ON STREET NAME'])
#null_data
null_data['N_LONG'] = 0
null_data['N_LAT'] = 0
for row in range(0,20):
    null_data['N_LONG'].iloc[row] = geocodelong(null_data['ON STREET NAME'].iloc[row])
    null_data['N_LAT'].iloc[row] = geocodelat(null_data['ON STREET NAME'].iloc[row])
null_data.head(20)
#null_data.apply(getlong(null_data['LONGITUDE']),axis=1)

# %%
url = 'https://data.cityofnewyork.us/api/geospatial/78dh-3ptz?method=export&format=GeoJSON' 
df_nyc = gpd.read_file(url)
ny_map = df_nyc.plot(linewidth=0.5, color='White', edgecolor = 'Black', figsize = (20,15), alpha=0.5)

#this calculation takes hella long, think about subsampling the data, also the heatmap didn't work even when testing with 20 points
data_test = null_data.head(20)
sns.kdeplot(
    data_test.N_LONG, data_test.N_LAT,
    gridsize = 100,
    cmap = plt.cm.Reds,
    shade = True,
    shade_lowest = False,
    n_levels = 10,
    alpha = .5,
    ax = ny_map)
